# %% [markdown]
# # Library

# %%
# !pip install datasets
# !pip install tokenizers
# !pip install transformers

# !pip install datasets transformers==4.28.0
# Out:
# Collecting tokenizers
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 8.7 MB/s eta 0:00:00
# Collecting huggingface_hub<0.18,>=0.16.4 (from tokenizers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18,>=0.16.4->tokenizers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<0.18,>=0.16.4->tokenizers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<0.18,>=0.16.4->tokenizers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<0.18,>=0.16.4->tokenizers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<0.18,>=0.16.4->tokenizers) (2023.7.22)
# Installing collected packages: huggingface_hub, tokenizers
# Successfully installed huggingface_hub-0.17.3 tokenizers-0.14.1
# Collecting datasets
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 8.0 MB/s eta 0:00:00
# Collecting transformers==4.28.0
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 74.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, dill, multiprocess, transformers, datasets
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
# Successfully installed datasets-2.14.6 dill-0.3.7 multiprocess-0.70.15 tokenizers-0.13.3 transformers-4.28.0

# %%
# !pip3 install tokenizers
# Out:
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (0.13.3)

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=569e87a91fbaae064e08561ea88600f00cb244a4a2a570879c87d2aae0bbacb2
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
from transformers import DataCollatorWithPadding,AutoModelForSequenceClassification, Trainer, TrainingArguments,AutoTokenizer,AutoModel,AutoConfig, DataCollatorForTokenClassification
from transformers.modeling_outputs import TokenClassifierOutput
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import datasets
from datasets import load_dataset,Dataset,DatasetDict,ClassLabel,Sequence

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load and process custom dataset

# %%
df = pd.read_csv('/content/combined_BIO.csv')

# %%
import ast

# Function to process the label column
def process_label(label):
    # Use ast.literal_eval to safely evaluate the content inside the brackets
    try:
        label_list = ast.literal_eval(label)
        if isinstance(label_list, list):
            if len(label_list) == 0:
                return [0]
            return label_list
    except (SyntaxError, ValueError):
        pass
    return [0]

# %%
df['content'] = df['content'].str.replace(r"[\[\]']", '', regex=True)

# %%
df['content'] = df['content'].apply(lambda x: x.split(" "))

# %%
# Apply the process_label function to each row in the label column
df['NER'] = df['NER'].apply(lambda x: x.replace("[[", "["))
df['NER'] = df['NER'].apply(lambda x: x.replace("]]", "]"))
df['NER'] = df['NER'].apply(process_label)


# Explode the label lists into separate rows
# df = df.explode('label', ignore_index=True)
# df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.rename(columns = {'content': 'tokens', 'NER':'ner_tags'}, inplace = True)

# %%
df = df.drop(['Unnamed: 0', 'label'], axis=1)

# %%
data = Dataset.from_pandas(df)

# %%
class_label = ["O", "B-Subject", "I-Subject", "B-Object", "I-Object", "B-Aspect", "I-Aspect", "B-Predicate", "I-Predicate"]
data = data.cast_column("ner_tags", datasets.Sequence(datasets.ClassLabel(names=class_label)))
# Out:
# Casting the dataset:   0%|          | 0/4807 [00:00<?, ? examples/s]

# %%
train_testvalid = data.train_test_split(test_size=0.2,seed=15)

# Split the 10% test + valid in half test, half valid
test_valid = train_testvalid['test'].train_test_split(test_size=0.5,seed=15)
dataset = DatasetDict({
    'train': train_testvalid['train'],
    'test': test_valid['test'],
    'validation': test_valid['train']})

# %%
label_names = dataset["train"].features["ner_tags"].feature.names

# %% [markdown]
# # Huggingface preprocessing

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("NlpHUST/ner-vietnamese-electra-base")

#Get the values for input_ids, token_type_ids, attention_mask
def tokenize_adjust_labels(all_samples_per_split):
  tokenized_samples = tokenizer.batch_encode_plus(all_samples_per_split["tokens"], is_split_into_words=True)
  #tokenized_samples is not a datasets object so this alone won't work with Trainer API, hence map is used
  #so the new keys [input_ids, labels (after adjustment)]
  #can be added to the datasets dict for each train test validation split
  total_adjusted_labels = []
  print(len(tokenized_samples["input_ids"]))
  for k in range(0, len(tokenized_samples["input_ids"])):
    prev_wid = -1
    word_ids_list = tokenized_samples.word_ids(batch_index=k)
    existing_label_ids = all_samples_per_split["ner_tags"][k]
    i = -1
    adjusted_label_ids = []

    for wid in word_ids_list:
      if(wid is None):
        adjusted_label_ids.append(-100)
      elif(wid!=prev_wid):
        i = i + 1
        adjusted_label_ids.append(existing_label_ids[i])
        prev_wid = wid
      else:
        label_name = label_names[existing_label_ids[i]]
        adjusted_label_ids.append(existing_label_ids[i])

    total_adjusted_labels.append(adjusted_label_ids)
  tokenized_samples["labels"] = total_adjusted_labels
  return tokenized_samples

tokenized_dataset = dataset.map(tokenize_adjust_labels, batched=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/411k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Map:   0%|          | 0/3845 [00:00<?, ? examples/s]
# 1000
# 1000
# 1000
# 845
# Map:   0%|          | 0/481 [00:00<?, ? examples/s]
# 481
# Map:   0%|          | 0/481 [00:00<?, ? examples/s]
# 481

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer)

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer
import numpy as np
from datasets import load_metric

# %%
metric = load_metric("seqeval")
# Out:
# <ipython-input-21-e20ba34f8cc7>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("seqeval")
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]

# %%
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    # Remove ignored index (special tokens)
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_names[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    flattened_results = {
        "overall_precision": results["overall_precision"],
        "overall_recall": results["overall_recall"],
        "overall_f1": results["overall_f1"],
        "overall_accuracy": results["overall_accuracy"],
    }
    for k in results.keys():
      if(k not in flattened_results.keys()):
        flattened_results[k+"_f1"]=results[k]["f1"]

    return flattened_results

# %%
len(label_names)
# Out:
# 9

# %%
id2label = {0: "O", 1: "B-Subject", 2: "I-Subject", 3: "B-Object", 4: "I-Object", 5: "B-Aspect", 6: "B-Aspect",
            7: "B-Predicate", 8: "I-Predicate"}

label2id = {"O": 0 , "B-Subject": 1, "I-Subject": 2 , "B-Object": 3, "I-Object": 4, "B-Aspect": 5, "B-Aspect": 6,
            "B-Predicate": 7, "I-Predicate": 8}

# %%
model = AutoModelForTokenClassification.from_pretrained("NlpHUST/ner-vietnamese-electra-base", num_labels=len(label_names), id2label=id2label, label2id=label2id)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/532M [00:00<?, ?B/s]

# %%
# for name, module in model.named_modules():
#   print(name)
# Out:
# electra
# electra.embeddings
# electra.embeddings.word_embeddings
# electra.embeddings.position_embeddings
# electra.embeddings.token_type_embeddings
# electra.embeddings.LayerNorm
# electra.embeddings.dropout
# electra.encoder
# electra.encoder.layer
# electra.encoder.layer.0
# electra.encoder.layer.0.attention
# electra.encoder.layer.0.attention.self
# electra.encoder.layer.0.attention.self.query
# electra.encoder.layer.0.attention.self.key
# electra.encoder.layer.0.attention.self.value
# electra.encoder.layer.0.attention.self.dropout
# electra.encoder.layer.0.attention.output
# electra.encoder.layer.0.attention.output.dense
# electra.encoder.layer.0.attention.output.LayerNorm
# electra.encoder.layer.0.attention.output.dropout
# electra.encoder.layer.0.intermediate
# electra.encoder.layer.0.intermediate.dense
# electra.encoder.layer.0.intermediate.intermediate_act_fn
# electra.encoder.layer.0.output
# electra.encoder.layer.0.output.dense
# electra.encoder.layer.0.output.LayerNorm
# electra.encoder.layer.0.output.dropout
# electra.encoder.layer.1
# electra.encoder.layer.1.attention
# electra.encoder.layer.1.attention.self
# electra.encoder.layer.1.attention.self.query
# electra.encoder.layer.1.attention.self.key
# electra.encoder.layer.1.attention.self.value
# electra.encoder.layer.1.attention.self.dropout
# electra.encoder.layer.1.attention.output
# electra.encoder.layer.1.attention.output.dense
# electra.encoder.layer.1.attention.output.LayerNorm
# electra.encoder.layer.1.attention.output.dropout
# electra.encoder.layer.1.intermediate
# electra.encoder.layer.1.intermediate.dense
# electra.encoder.layer.1.intermediate.intermediate_act_fn
# electra.encoder.layer.1.output
# electra.encoder.layer.1.output.dense
# electra.encoder.layer.1.output.LayerNorm
# electra.encoder.layer.1.output.dropout
# electra.encoder.layer.2
# electra.encoder.layer.2.attention
# electra.encoder.layer.2.attention.self
# electra.encoder.layer.2.attention.self.query
# electra.encoder.layer.2.attention.self.key
# electra.encoder.layer.2.attention.self.value
# electra.encoder.layer.2.attention.self.dropout
# electra.encoder.layer.2.attention.output
# electra.encoder.layer.2.attention.output.dense
# electra.encoder.layer.2.attention.output.LayerNorm
# electra.encoder.layer.2.attention.output.dropout
# electra.encoder.layer.2.intermediate
# electra.encoder.layer.2.intermediate.dense
# electra.encoder.layer.2.intermediate.intermediate_act_fn
# electra.encoder.layer.2.output
# electra.encoder.layer.2.output.dense
# electra.encoder.layer.2.output.LayerNorm
# electra.encoder.layer.2.output.dropout
# electra.encoder.layer.3
# electra.encoder.layer.3.attention
# electra.encoder.layer.3.attention.self
# electra.encoder.layer.3.attention.self.query
# electra.encoder.layer.3.attention.self.key
# electra.encoder.layer.3.attention.self.value
# electra.encoder.layer.3.attention.self.dropout
# electra.encoder.layer.3.attention.output
# electra.encoder.layer.3.attention.output.dense
# electra.encoder.layer.3.attention.output.LayerNorm
# electra.encoder.layer.3.attention.output.dropout
# electra.encoder.layer.3.intermediate
# electra.encoder.layer.3.intermediate.dense
# electra.encoder.layer.3.intermediate.intermediate_act_fn
# electra.encoder.layer.3.output
# electra.encoder.layer.3.output.dense
# electra.encoder.layer.3.output.LayerNorm
# electra.encoder.layer.3.output.dropout
# electra.encoder.layer.4
# electra.encoder.layer.4.attention
# electra.encoder.layer.4.attention.self
# electra.encoder.layer.4.attention.self.query
# electra.encoder.layer.4.attention.self.key
# electra.encoder.layer.4.attention.self.value
# electra.encoder.layer.4.attention.self.dropout
# electra.encoder.layer.4.attention.output
# electra.encoder.layer.4.attention.output.dense
# electra.encoder.layer.4.attention.output.LayerNorm
# electra.encoder.layer.4.attention.output.dropout
# electra.encoder.layer.4.intermediate
# electra.encoder.layer.4.intermediate.dense
# electra.encoder.layer.4.intermediate.intermediate_act_fn
# electra.encoder.layer.4.output
# electra.encoder.layer.4.output.dense
# electra.encoder.layer.4.output.LayerNorm
# electra.encoder.layer.4.output.dropout
# electra.encoder.layer.5
# electra.encoder.layer.5.attention
# electra.encoder.layer.5.attention.self
# electra.encoder.layer.5.attention.self.query
# electra.encoder.layer.5.attention.self.key
# electra.encoder.layer.5.attention.self.value
# electra.encoder.layer.5.attention.self.dropout
# electra.encoder.layer.5.attention.output
# electra.encoder.layer.5.attention.output.dense
# electra.encoder.layer.5.attention.output.LayerNorm
# electra.encoder.layer.5.attention.output.dropout
# electra.encoder.layer.5.intermediate
# electra.encoder.layer.5.intermediate.dense
# electra.encoder.layer.5.intermediate.intermediate_act_fn
# electra.encoder.layer.5.output
# electra.encoder.layer.5.output.dense
# electra.encoder.layer.5.output.LayerNorm
# electra.encoder.layer.5.output.dropout
# electra.encoder.layer.6
# electra.encoder.layer.6.attention
# electra.encoder.layer.6.attention.self
# electra.encoder.layer.6.attention.self.query
# electra.encoder.layer.6.attention.self.key
# electra.encoder.layer.6.attention.self.value
# electra.encoder.layer.6.attention.self.dropout
# electra.encoder.layer.6.attention.output
# electra.encoder.layer.6.attention.output.dense
# electra.encoder.layer.6.attention.output.LayerNorm
# electra.encoder.layer.6.attention.output.dropout
# electra.encoder.layer.6.intermediate
# electra.encoder.layer.6.intermediate.dense
# electra.encoder.layer.6.intermediate.intermediate_act_fn
# electra.encoder.layer.6.output
# electra.encoder.layer.6.output.dense
# electra.encoder.layer.6.output.LayerNorm
# electra.encoder.layer.6.output.dropout
# electra.encoder.layer.7
# electra.encoder.layer.7.attention
# electra.encoder.layer.7.attention.self
# electra.encoder.layer.7.attention.self.query
# electra.encoder.layer.7.attention.self.key
# electra.encoder.layer.7.attention.self.value
# electra.encoder.layer.7.attention.self.dropout
# electra.encoder.layer.7.attention.output
# electra.encoder.layer.7.attention.output.dense
# electra.encoder.layer.7.attention.output.LayerNorm
# electra.encoder.layer.7.attention.output.dropout
# electra.encoder.layer.7.intermediate
# electra.encoder.layer.7.intermediate.dense
# electra.encoder.layer.7.intermediate.intermediate_act_fn
# electra.encoder.layer.7.output
# electra.encoder.layer.7.output.dense
# electra.encoder.layer.7.output.LayerNorm
# electra.encoder.layer.7.output.dropout
# electra.encoder.layer.8
# electra.encoder.layer.8.attention
# electra.encoder.layer.8.attention.self
# electra.encoder.layer.8.attention.self.query
# electra.encoder.layer.8.attention.self.key
# electra.encoder.layer.8.attention.self.value
# electra.encoder.layer.8.attention.self.dropout
# electra.encoder.layer.8.attention.output
# electra.encoder.layer.8.attention.output.dense
# electra.encoder.layer.8.attention.output.LayerNorm
# electra.encoder.layer.8.attention.output.dropout
# electra.encoder.layer.8.intermediate
# electra.encoder.layer.8.intermediate.dense
# electra.encoder.layer.8.intermediate.intermediate_act_fn
# electra.encoder.layer.8.output
# electra.encoder.layer.8.output.dense
# electra.encoder.layer.8.output.LayerNorm
# electra.encoder.layer.8.output.dropout
# electra.encoder.layer.9
# electra.encoder.layer.9.attention
# electra.encoder.layer.9.attention.self
# electra.encoder.layer.9.attention.self.query
# electra.encoder.layer.9.attention.self.key
# electra.encoder.layer.9.attention.self.value
# electra.encoder.layer.9.attention.self.dropout
# electra.encoder.layer.9.attention.output
# electra.encoder.layer.9.attention.output.dense
# electra.encoder.layer.9.attention.output.LayerNorm
# electra.encoder.layer.9.attention.output.dropout
# electra.encoder.layer.9.intermediate
# electra.encoder.layer.9.intermediate.dense
# electra.encoder.layer.9.intermediate.intermediate_act_fn
# electra.encoder.layer.9.output
# electra.encoder.layer.9.output.dense
# electra.encoder.layer.9.output.LayerNorm
# electra.encoder.layer.9.output.dropout
# electra.encoder.layer.10
# electra.encoder.layer.10.attention
# electra.encoder.layer.10.attention.self
# electra.encoder.layer.10.attention.self.query
# electra.encoder.layer.10.attention.self.key
# electra.encoder.layer.10.attention.self.value
# electra.encoder.layer.10.attention.self.dropout
# electra.encoder.layer.10.attention.output
# electra.encoder.layer.10.attention.output.dense
# electra.encoder.layer.10.attention.output.LayerNorm
# electra.encoder.layer.10.attention.output.dropout
# electra.encoder.layer.10.intermediate
# electra.encoder.layer.10.intermediate.dense
# electra.encoder.layer.10.intermediate.intermediate_act_fn
# electra.encoder.layer.10.output
# electra.encoder.layer.10.output.dense
# electra.encoder.layer.10.output.LayerNorm
# electra.encoder.layer.10.output.dropout
# electra.encoder.layer.11
# electra.encoder.layer.11.attention
# electra.encoder.layer.11.attention.self
# electra.encoder.layer.11.attention.self.query
# electra.encoder.layer.11.attention.self.key
# electra.encoder.layer.11.attention.self.value
# electra.encoder.layer.11.attention.self.dropout
# electra.encoder.layer.11.attention.output
# electra.encoder.layer.11.attention.output.dense
# electra.encoder.layer.11.attention.output.LayerNorm
# electra.encoder.layer.11.attention.output.dropout
# electra.encoder.layer.11.intermediate
# electra.encoder.layer.11.intermediate.dense
# electra.encoder.layer.11.intermediate.intermediate_act_fn
# electra.encoder.layer.11.output
# electra.encoder.layer.11.output.dense
# electra.encoder.layer.11.output.LayerNorm
# electra.encoder.layer.11.output.dropout
# dropout
# classifier

# %%
# for name, module in model.named_modules():
#   freeze_list = [".embeddings", ".layer.0.", ".layer.1.", ".layer.2.", ".layer.3.", ".layer.4."]
#   for layer in freeze_list:
#     if layer in name:
#       for param in module.parameters():
#         param.requires_grad = False

# %%
# for name, module in model.named_modules():
#     for param in module.parameters():
#         if param.requires_grad == True:
#           print(name)
#           break
# Out:
# electra
# electra.encoder
# electra.encoder.layer
# electra.encoder.layer.4
# electra.encoder.layer.4.attention
# electra.encoder.layer.4.attention.self
# electra.encoder.layer.4.attention.self.query
# electra.encoder.layer.4.attention.self.key
# electra.encoder.layer.4.attention.self.value
# electra.encoder.layer.4.attention.output
# electra.encoder.layer.4.attention.output.dense
# electra.encoder.layer.4.attention.output.LayerNorm
# electra.encoder.layer.4.intermediate
# electra.encoder.layer.4.intermediate.dense
# electra.encoder.layer.4.output
# electra.encoder.layer.4.output.dense
# electra.encoder.layer.4.output.LayerNorm
# electra.encoder.layer.5
# electra.encoder.layer.5.attention
# electra.encoder.layer.5.attention.self
# electra.encoder.layer.5.attention.self.query
# electra.encoder.layer.5.attention.self.key
# electra.encoder.layer.5.attention.self.value
# electra.encoder.layer.5.attention.output
# electra.encoder.layer.5.attention.output.dense
# electra.encoder.layer.5.attention.output.LayerNorm
# electra.encoder.layer.5.intermediate
# electra.encoder.layer.5.intermediate.dense
# electra.encoder.layer.5.output
# electra.encoder.layer.5.output.dense
# electra.encoder.layer.5.output.LayerNorm
# electra.encoder.layer.6
# electra.encoder.layer.6.attention
# electra.encoder.layer.6.attention.self
# electra.encoder.layer.6.attention.self.query
# electra.encoder.layer.6.attention.self.key
# electra.encoder.layer.6.attention.self.value
# electra.encoder.layer.6.attention.output
# electra.encoder.layer.6.attention.output.dense
# electra.encoder.layer.6.attention.output.LayerNorm
# electra.encoder.layer.6.intermediate
# electra.encoder.layer.6.intermediate.dense
# electra.encoder.layer.6.output
# electra.encoder.layer.6.output.dense
# electra.encoder.layer.6.output.LayerNorm
# electra.encoder.layer.7
# electra.encoder.layer.7.attention
# electra.encoder.layer.7.attention.self
# electra.encoder.layer.7.attention.self.query
# electra.encoder.layer.7.attention.self.key
# electra.encoder.layer.7.attention.self.value
# electra.encoder.layer.7.attention.output
# electra.encoder.layer.7.attention.output.dense
# electra.encoder.layer.7.attention.output.LayerNorm
# electra.encoder.layer.7.intermediate
# electra.encoder.layer.7.intermediate.dense
# electra.encoder.layer.7.output
# electra.encoder.layer.7.output.dense
# electra.encoder.layer.7.output.LayerNorm
# electra.encoder.layer.8
# electra.encoder.layer.8.attention
# electra.encoder.layer.8.attention.self
# electra.encoder.layer.8.attention.self.query
# electra.encoder.layer.8.attention.self.key
# electra.encoder.layer.8.attention.self.value
# electra.encoder.layer.8.attention.output
# electra.encoder.layer.8.attention.output.dense
# electra.encoder.layer.8.attention.output.LayerNorm
# electra.encoder.layer.8.intermediate
# electra.encoder.layer.8.intermediate.dense
# electra.encoder.layer.8.output
# electra.encoder.layer.8.output.dense
# electra.encoder.layer.8.output.LayerNorm
# electra.encoder.layer.9
# electra.encoder.layer.9.attention
# electra.encoder.layer.9.attention.self
# electra.encoder.layer.9.attention.self.query
# electra.encoder.layer.9.attention.self.key
# electra.encoder.layer.9.attention.self.value
# electra.encoder.layer.9.attention.output
# electra.encoder.layer.9.attention.output.dense
# electra.encoder.layer.9.attention.output.LayerNorm
# electra.encoder.layer.9.intermediate
# electra.encoder.layer.9.intermediate.dense
# electra.encoder.layer.9.output
# electra.encoder.layer.9.output.dense
# electra.encoder.layer.9.output.LayerNorm
# electra.encoder.layer.10
# electra.encoder.layer.10.attention
# electra.encoder.layer.10.attention.self
# electra.encoder.layer.10.attention.self.query
# electra.encoder.layer.10.attention.self.key
# electra.encoder.layer.10.attention.self.value
# electra.encoder.layer.10.attention.output
# electra.encoder.layer.10.attention.output.dense
# electra.encoder.layer.10.attention.output.LayerNorm
# electra.encoder.layer.10.intermediate
# electra.encoder.layer.10.intermediate.dense
# electra.encoder.layer.10.output
# electra.encoder.layer.10.output.dense
# electra.encoder.layer.10.output.LayerNorm
# electra.encoder.layer.11
# electra.encoder.layer.11.attention
# electra.encoder.layer.11.attention.self
# electra.encoder.layer.11.attention.self.query
# electra.encoder.layer.11.attention.self.key
# electra.encoder.layer.11.attention.self.value
# electra.encoder.layer.11.attention.output
# electra.encoder.layer.11.attention.output.dense
# electra.encoder.layer.11.attention.output.LayerNorm
# electra.encoder.layer.11.intermediate
# electra.encoder.layer.11.intermediate.dense
# electra.encoder.layer.11.output
# electra.encoder.layer.11.output.dense
# electra.encoder.layer.11.output.LayerNorm
# classifier

# %%
model.num_parameters(only_trainable = True)
# Out:
# 49622025

# %%
model.num_parameters(only_trainable = False)
# Out:
# 133073673

# %%
batch_size = 128
training_args = TrainingArguments(
output_dir="results",
num_train_epochs=40,
per_device_train_batch_size=batch_size,
per_device_eval_batch_size=batch_size,
evaluation_strategy="epoch",
disable_tqdm=False,
logging_steps=len(tokenized_dataset['train']) // batch_size)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a ElectraTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1240' max='1240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1240/1240 31:51, Epoch 40/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#       <th>Aspect F1</th>
#       <th>Object F1</th>
#       <th>Predicate F1</th>
#       <th>Subject F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.740400</td>
#       <td>0.643881</td>
#       <td>0.423688</td>
#       <td>0.485649</td>
#       <td>0.452558</td>
#       <td>0.788322</td>
#       <td>0.404539</td>
#       <td>0.328152</td>
#       <td>0.552394</td>
#       <td>0.452640</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.432100</td>
#       <td>0.254490</td>
#       <td>0.748652</td>
#       <td>0.822323</td>
#       <td>0.783760</td>
#       <td>0.923092</td>
#       <td>0.758287</td>
#       <td>0.754783</td>
#       <td>0.807799</td>
#       <td>0.800349</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.206700</td>
#       <td>0.156064</td>
#       <td>0.840742</td>
#       <td>0.887472</td>
#       <td>0.863475</td>
#       <td>0.954857</td>
#       <td>0.835517</td>
#       <td>0.818342</td>
#       <td>0.900494</td>
#       <td>0.873484</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.113800</td>
#       <td>0.128984</td>
#       <td>0.880952</td>
#       <td>0.910251</td>
#       <td>0.895362</td>
#       <td>0.965204</td>
#       <td>0.871607</td>
#       <td>0.875000</td>
#       <td>0.918498</td>
#       <td>0.905226</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.074900</td>
#       <td>0.111067</td>
#       <td>0.894967</td>
#       <td>0.931663</td>
#       <td>0.912946</td>
#       <td>0.970805</td>
#       <td>0.912152</td>
#       <td>0.876522</td>
#       <td>0.939007</td>
#       <td>0.899911</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.051200</td>
#       <td>0.095132</td>
#       <td>0.923214</td>
#       <td>0.942141</td>
#       <td>0.932582</td>
#       <td>0.976012</td>
#       <td>0.922049</td>
#       <td>0.921960</td>
#       <td>0.950820</td>
#       <td>0.927690</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.039500</td>
#       <td>0.095624</td>
#       <td>0.921847</td>
#       <td>0.945786</td>
#       <td>0.933663</td>
#       <td>0.977066</td>
#       <td>0.917526</td>
#       <td>0.920354</td>
#       <td>0.952790</td>
#       <td>0.936057</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.027600</td>
#       <td>0.087966</td>
#       <td>0.921708</td>
#       <td>0.943964</td>
#       <td>0.932703</td>
#       <td>0.977857</td>
#       <td>0.923304</td>
#       <td>0.911032</td>
#       <td>0.952722</td>
#       <td>0.930027</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.020100</td>
#       <td>0.079623</td>
#       <td>0.928762</td>
#       <td>0.950342</td>
#       <td>0.939428</td>
#       <td>0.980822</td>
#       <td>0.933135</td>
#       <td>0.927176</td>
#       <td>0.953538</td>
#       <td>0.935569</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.020100</td>
#       <td>0.088553</td>
#       <td>0.935354</td>
#       <td>0.955809</td>
#       <td>0.945471</td>
#       <td>0.980032</td>
#       <td>0.932642</td>
#       <td>0.942652</td>
#       <td>0.959198</td>
#       <td>0.945230</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.015300</td>
#       <td>0.082812</td>
#       <td>0.937611</td>
#       <td>0.958542</td>
#       <td>0.947961</td>
#       <td>0.981086</td>
#       <td>0.937870</td>
#       <td>0.944544</td>
#       <td>0.960686</td>
#       <td>0.945970</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.014600</td>
#       <td>0.085335</td>
#       <td>0.928508</td>
#       <td>0.952620</td>
#       <td>0.940409</td>
#       <td>0.980625</td>
#       <td>0.929682</td>
#       <td>0.925267</td>
#       <td>0.960573</td>
#       <td>0.935909</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.012000</td>
#       <td>0.086372</td>
#       <td>0.938283</td>
#       <td>0.955809</td>
#       <td>0.946965</td>
#       <td>0.981745</td>
#       <td>0.932543</td>
#       <td>0.944742</td>
#       <td>0.963493</td>
#       <td>0.944840</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.009900</td>
#       <td>0.087184</td>
#       <td>0.940018</td>
#       <td>0.956720</td>
#       <td>0.948295</td>
#       <td>0.981350</td>
#       <td>0.936012</td>
#       <td>0.941385</td>
#       <td>0.963493</td>
#       <td>0.947556</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.009400</td>
#       <td>0.079346</td>
#       <td>0.940466</td>
#       <td>0.957175</td>
#       <td>0.948747</td>
#       <td>0.983590</td>
#       <td>0.936990</td>
#       <td>0.953571</td>
#       <td>0.961953</td>
#       <td>0.944099</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.008200</td>
#       <td>0.084912</td>
#       <td>0.941282</td>
#       <td>0.956720</td>
#       <td>0.948938</td>
#       <td>0.982997</td>
#       <td>0.932342</td>
#       <td>0.962162</td>
#       <td>0.964235</td>
#       <td>0.943262</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.006800</td>
#       <td>0.086358</td>
#       <td>0.943422</td>
#       <td>0.957175</td>
#       <td>0.950249</td>
#       <td>0.982272</td>
#       <td>0.935316</td>
#       <td>0.956835</td>
#       <td>0.967049</td>
#       <td>0.944000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.007000</td>
#       <td>0.088194</td>
#       <td>0.946275</td>
#       <td>0.954897</td>
#       <td>0.950567</td>
#       <td>0.982404</td>
#       <td>0.939417</td>
#       <td>0.953405</td>
#       <td>0.964824</td>
#       <td>0.944742</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.005700</td>
#       <td>0.086430</td>
#       <td>0.944719</td>
#       <td>0.957631</td>
#       <td>0.951131</td>
#       <td>0.983063</td>
#       <td>0.938988</td>
#       <td>0.954792</td>
#       <td>0.967001</td>
#       <td>0.944198</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.005800</td>
#       <td>0.091125</td>
#       <td>0.939937</td>
#       <td>0.955353</td>
#       <td>0.947582</td>
#       <td>0.982206</td>
#       <td>0.935123</td>
#       <td>0.951699</td>
#       <td>0.964875</td>
#       <td>0.938992</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.004600</td>
#       <td>0.085417</td>
#       <td>0.941282</td>
#       <td>0.956720</td>
#       <td>0.948938</td>
#       <td>0.983327</td>
#       <td>0.936012</td>
#       <td>0.951699</td>
#       <td>0.967742</td>
#       <td>0.939716</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.004300</td>
#       <td>0.096686</td>
#       <td>0.941573</td>
#       <td>0.954442</td>
#       <td>0.947964</td>
#       <td>0.981284</td>
#       <td>0.935821</td>
#       <td>0.965766</td>
#       <td>0.964875</td>
#       <td>0.932743</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.004300</td>
#       <td>0.086939</td>
#       <td>0.938757</td>
#       <td>0.956720</td>
#       <td>0.947653</td>
#       <td>0.982734</td>
#       <td>0.934718</td>
#       <td>0.955277</td>
#       <td>0.964875</td>
#       <td>0.938053</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.003800</td>
#       <td>0.085859</td>
#       <td>0.935053</td>
#       <td>0.957631</td>
#       <td>0.946208</td>
#       <td>0.983063</td>
#       <td>0.939169</td>
#       <td>0.932624</td>
#       <td>0.964875</td>
#       <td>0.938380</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.004400</td>
#       <td>0.087224</td>
#       <td>0.939259</td>
#       <td>0.958087</td>
#       <td>0.948579</td>
#       <td>0.983195</td>
#       <td>0.940476</td>
#       <td>0.939286</td>
#       <td>0.967001</td>
#       <td>0.940141</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.003200</td>
#       <td>0.085205</td>
#       <td>0.942678</td>
#       <td>0.958998</td>
#       <td>0.950768</td>
#       <td>0.983590</td>
#       <td>0.940565</td>
#       <td>0.956835</td>
#       <td>0.964183</td>
#       <td>0.943363</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.003300</td>
#       <td>0.090881</td>
#       <td>0.945691</td>
#       <td>0.959909</td>
#       <td>0.952747</td>
#       <td>0.982800</td>
#       <td>0.940299</td>
#       <td>0.9620
# TrainOutput(global_step=1240, training_loss=0.09395604309430647, metrics={'train_runtime': 1916.3782, 'train_samples_per_second': 80.256, 'train_steps_per_second': 0.647, 'total_flos': 6295064796272484.0, 'train_loss': 0.09395604309430647, 'epoch': 40.0})

# %%
predictions, labels, _ = trainer.predict(tokenized_dataset["test"])

predictions = np.argmax(predictions, axis=2)

# Remove ignored index (special tokens)

true_predictions = [

[label_names[p] for (p, l) in zip(prediction, label) if l != -100]

for prediction, label in zip(predictions, labels)

]

true_labels = [

[label_names[l] for (p, l) in zip(prediction, label) if l != -100]

for prediction, label in zip(predictions, labels)

]

results = metric.compute(predictions=true_predictions, references=true_labels)

results
# Out:
# {'Aspect': {'precision': 0.9276923076923077,
#   'recall': 0.9481132075471698,
#   'f1': 0.9377916018662519,
#   'number': 636},
#  'Object': {'precision': 0.931899641577061,
#   'recall': 0.966542750929368,
#   'f1': 0.9489051094890512,
#   'number': 269},
#  'Predicate': {'precision': 0.967605633802817,
#   'recall': 0.9800285306704708,
#   'f1': 0.9737774627923459,
#   'number': 701},
#  'Subject': {'precision': 0.9531772575250836,
#   'recall': 0.946843853820598,
#   'f1': 0.95,
#   'number': 602},
#  'overall_precision': 0.9476978095663835,
#  'overall_recall': 0.9601449275362319,
#  'overall_f1': 0.9538807649043869,
#  'overall_accuracy': 0.9857813806858393}

# %%
trainer.save_model("/content/drive/MyDrive/baseline_models/electra_new_data")

# %%
len(trainer.state.log_history)
# Out:
# 41

# %%
import matplotlib.pyplot as plt

loss_list = []
val_loss_list = []
for i in range(0, len(trainer.state.log_history)):
  if "eval_loss" in trainer.state.log_history[i].keys():
    val_loss_list.append(trainer.state.log_history[i]["eval_loss"])
  if "loss" in trainer.state.log_history[i].keys():
    loss_list.append(trainer.state.log_history[i]["loss"])
  if "eval_loss" in trainer.state.log_history[i].keys() and "loss" in trainer.state.log_history[i].keys():
    print(trainer.state.log_history[i])

# %%
plt.plot(loss_list)

# %%
plt.plot(val_loss_list)

# %% [markdown]
# # Inference

# %%
from transformers import pipeline
from transformers import AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained("NlpHUST/ner-vietnamese-electra-base")
model_test = AutoModelForTokenClassification.from_pretrained("/content/drive/MyDrive/baseline_models/electra_new_data")
nlp = pipeline("token-classification", model=model_test, tokenizer=tokenizer)
example = "điện thoại A tốt hơn điện thoại B ."
ner_results = nlp(example)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
ner_results
# Out:
# [{'entity': 'B-Subject',
#   'score': 0.9995492,
#   'index': 1,
#   'word': 'điê',
#   'start': 0,
#   'end': 3},
#  {'entity': 'B-Subject',
#   'score': 0.9993622,
#   'index': 2,
#   'word': '##̣',
#   'start': 3,
#   'end': 4},
#  {'entity': 'B-Subject',
#   'score': 0.9995889,
#   'index': 3,
#   'word': '##n',
#   'start': 4,
#   'end': 5},
#  {'entity': 'I-Subject',
#   'score': 0.9993875,
#   'index': 4,
#   'word': 'thoa',
#   'start': 6,
#   'end': 10},
#  {'entity': 'I-Subject',
#   'score': 0.9991673,
#   'index': 5,
#   'word': '##̣',
#   'start': 10,
#   'end': 11},
#  {'entity': 'I-Subject',
#   'score': 0.9989951,
#   'index': 6,
#   'word': '##i',
#   'start': 11,
#   'end': 12},
#  {'entity': 'I-Subject',
#   'score': 0.99935037,
#   'index': 7,
#   'word': 'A',
#   'start': 13,
#   'end': 14},
#  {'entity': 'B-Predicate',
#   'score': 0.9993724,
#   'index': 8,
#   'word': 'tô',
#   'start': 15,
#   'end': 17},
#  {'entity': 'B-Predicate',
#   'score': 0.9993789,
#   'index': 9,
#   'word': '##́',
#   'start': 17,
#   'end': 18},
#  {'entity': 'B-Predicate',
#   'score': 0.9990983,
#   'index': 10,
#   'word': '##t',
#   'start': 18,
#   'end': 19},
#  {'entity': 'I-Predicate',
#   'score': 0.9998086,
#   'index': 11,
#   'word': 'hơn',
#   'start': 20,
#   'end': 23},
#  {'entity': 'B-Object',
#   'score': 0.9994141,
#   'index': 12,
#   'word': 'điê',
#   'start': 24,
#   'end': 27},
#  {'entity': 'B-Object',
#   'score': 0.9989686,
#   'index': 13,
#   'word': '##̣',
#   'start': 27,
#   'end': 28},
#  {'entity': 'B-Object',
#   'score': 0.9990306,
#   'index': 14,
#   'word': '##n',
#   'start': 28,
#   'end': 29},
#  {'entity': 'I-Object',
#   'score': 0.9995384,
#   'index': 15,
#   'word': 'thoa',
#   'start': 30,
#   'end': 34},
#  {'entity': 'I-Object',
#   'score': 0.9995671,
#   'index': 16,
#   'word': '##̣',
#   'start': 34,
#   'end': 35},
#  {'entity': 'I-Object',
#   'score': 0.9995229,
#   'index': 17,
#   'word': '##i',
#   'start': 35,
#   'end': 36},
#  {'entity': 'I-Object',
#   'score': 0.9994678,
#   'index': 18,
#   'word': 'B',
#   'start': 37,
#   'end': 38}]

# %%
model_test.num_parameters()
# Out:
# 133073673

# %%
model_test.num_parameters(only_trainable = True)
# Out:
# 133073673

# %%
model_test.num_parameters(only_trainable = False)
# Out:
# 133073673

# %%
ner_results
# Out:
# [{'entity': 'B-Subject',
#   'score': 0.98855746,
#   'index': 1,
#   'word': 'iPhone',
#   'start': 0,
#   'end': 6},
#  {'entity': 'I-Subject',
#   'score': 0.9809686,
#   'index': 2,
#   'word': '14',
#   'start': 7,
#   'end': 9},
#  {'entity': 'I-Subject',
#   'score': 0.9936767,
#   'index': 3,
#   'word': 'Pro',
#   'start': 10,
#   'end': 13},
#  {'entity': 'I-Subject',
#   'score': 0.99559397,
#   'index': 4,
#   'word': 'Max',
#   'start': 14,
#   'end': 17},
#  {'entity': 'B-Object',
#   'score': 0.97260094,
#   'index': 8,
#   'word': 'Google',
#   'start': 28,
#   'end': 34},
#  {'entity': 'I-Object',
#   'score': 0.9933867,
#   'index': 9,
#   'word': 'Pixel',
#   'start': 35,
#   'end': 40},
#  {'entity': 'I-Object',
#   'score': 0.9938904,
#   'index': 10,
#   'word': '7',
#   'start': 41,
#   'end': 42},
#  {'entity': 'I-Object',
#   'score': 0.9926891,
#   'index': 11,
#   'word': 'Pro',
#   'start': 43,
#   'end': 46},
#  {'entity': 'B-Predicate',
#   'score': 0.979772,
#   'index': 12,
#   'word': 'đê',
#   'start': 47,
#   'end': 49},
#  {'entity': 'B-Predicate',
#   'score': 0.97454405,
#   'index': 13,
#   'word': '##̀',
#   'start': 49,
#   'end': 50},
#  {'entity': 'B-Predicate',
#   'score': 0.9860598,
#   'index': 14,
#   'word': '##u',
#   'start': 50,
#   'end': 51},
#  {'entity': 'I-Predicate',
#   'score': 0.99138063,
#   'index': 15,
#   'word': 'la',
#   'start': 52,
#   'end': 54},
#  {'entity': 'I-Predicate',
#   'score': 0.9954543,
#   'index': 16,
#   'word': '##̀',
#   'start': 54,
#   'end': 55},
#  {'entity': 'I-Predicate',
#   'score': 0.9929403,
#   'index': 17,
#   'word': 'những',
#   'start': 56,
#   'end': 62},
#  {'entity': 'I-Predicate',
#   'score': 0.99728966,
#   'index': 18,
#   'word': 'điê',
#   'start': 63,
#   'end': 66},
#  {'entity': 'I-Predicate',
#   'score': 0.9972274,
#   'index': 19,
#   'word': '##̣',
#   'start': 66,
#   'end': 67},
#  {'entity': 'I-Predicate',
#   'score': 0.9942022,
#   'index': 20,
#   'word': '##n',
#   'start': 67,
#   'end': 68},
#  {'entity': 'I-Predicate',
#   'score': 0.9983455,
#   'index': 21,
#   'word': 'thoa',
#   'start': 69,
#   'end': 73},
#  {'entity': 'I-Predicate',
#   'score': 0.9978515,
#   'index': 22,
#   'word': '##̣',
#   'start': 73,
#   'end': 74},
#  {'entity': 'I-Predicate',
#   'score': 0.99673957,
#   'index': 23,
#   'word': '##i',
#   'start': 74,
#   'end': 75},
#  {'entity': 'I-Predicate',
#   'score': 0.99184775,
#   'index': 24,
#   'word': 'tô',
#   'start': 76,
#   'end': 78},
#  {'entity': 'I-Predicate',
#   'score': 0.98533744,
#   'index': 25,
#   'word': '##́',
#   'start': 78,
#   'end': 79},
#  {'entity': 'I-Predicate',
#   'score': 0.9840015,
#   'index': 26,
#   'word': '##t',
#   'start': 79,
#   'end': 80},
#  {'entity': 'I-Predicate',
#   'score': 0.9970939,
#   'index': 27,
#   'word': 'nhâ',
#   'start': 81,
#   'end': 84},
#  {'entity': 'I-Predicate',
#   'score': 0.99578106,
#   'index': 28,
#   'word': '##́',
#   'start': 84,
#   'end': 85},
#  {'entity': 'I-Predicate',
#   'score': 0.9949397,
#   'index': 29,
#   'word': '##t',
#   'start': 85,
#   'end': 86},
#  {'entity': 'I-Predicate',
#   'score': 0.9968245,
#   'index': 30,
#   'word': 'hiê',
#   'start': 87,
#   'end': 90},
#  {'entity': 'I-Predicate',
#   'score': 0.997233,
#   'index': 31,
#   'word': '##̣',
#   'start': 90,
#   'end': 91},
#  {'entity': 'I-Predicate',
#   'score': 0.99367285,
#   'index': 32,
#   'word': '##n',
#   'start': 91,
#   'end': 92},
#  {'entity': 'I-Predicate',
#   'score': 0.9978331,
#   'index': 33,
#   'word': 'nay',
#   'start': 93,
#   'end': 96}]
